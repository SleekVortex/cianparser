# %%
import time
import pandas as pd

from cianparser.cianparser import CianParser

# %%
parser = CianParser('Москва')

# %%
n_pages = 53
rooms = (1, 2, 3, 4, 5, 'studio')

# %%
data = []
for room in rooms:
    for n_page in range(1, n_pages+1):
        flats = parser.get_flats(
            deal_type="sale", rooms=(room,),
            with_saving_csv=True,
            additional_settings={"start_page":n_page, "end_page":n_page},
            with_extra_data=True
        )
        data.extend(flats)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\user\Desktop\Учеба\вкр\Мой парсер\cianparser\cian_flat_sale_1_1_moskva_22_Oct_2024_23_30_24_857550.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 244 208 852 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\user\Desktop\Учеба\вкр\Мой парсер\cianparser\cian_flat_sale_2_2_moskva_22_Oct_2024_23_30_33_328749.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       2 for room in rooms:
#       3     for n_page in range(1, n_pages+1):
# ----> 4         flats = parser.get_flats(deal_type="sale", rooms=(room,), with_saving_csv=True, additional_settings={"start_page":n_page, "end_page":n_page})
#       5         data.extend(flats)
#
# File c:\Users\user\Desktop\Учеба\вкр\Мой парсер\cianparser\cianparser\cianparser.py:119, in CianParser.get_flats(self, deal_type, rooms, with_saving_csv, with_extra_data, additional_settings)
#     108 deal_type, rent_period_type = __define_deal_type__(deal_type)
#     109 self.__parser__ = FlatListPageParser(
#     110     session=self.__session__,
#     111     accommodation_type="flat",
#    (...)
#     117     additional_settings=additional_settings,
#     118 )
# --> 119 self.__run__(
#     120     __build_url_list__(location_id=self.__location_id__, deal_type=deal_type, accommodation_type="flat",
#     121                        rooms=rooms, rent_period_type=rent_period_type,
#     122                        additional_settings=additional_settings))
#     123 return self.__parser__.result
#
# File c:\Users\user\Desktop\Учеба\вкр\Мой парсер\cianparser\cianparser\cianparser.py:75, in CianParser.__run__(self, url_list_format)
#      73 while attempt_number_exception < 3 and not page_parsed:
#      74     try:
# ---> 75         (page_parsed, attempt_number, end_all_parsing) = self.__parser__.parse_list_offers_page(
#      76             html=self.__load_list_page__(url_list_format=url_list_format, page_number=page_number, attempt_number_exception=attempt_number_exception),
#      77             page_number=page_number,
#      78             count_of_pages=self.__parser__.end_page + 1 - self.__parser__.start_page,
#      79             attempt_number=attempt_number_exception)
#      81     except Exception as e:
#      82         attempt_number_exception += 1
#
# File c:\Users\user\Desktop\Учеба\вкр\Мой парсер\cianparser\cianparser\flat\list.py:20, in FlatListPageParser.parse_list_offers_page(self, html, page_number, count_of_pages, attempt_number)
#      19 def parse_list_offers_page(self, html, page_number: int, count_of_pages: int, attempt_number: int):
# ---> 20     list_soup = bs4.BeautifulSoup(html, 'html.parser')
#      22     if list_soup.text.find("Captcha") > 0:
#      23         print(f"\r{page_number} page: there is CAPTCHA... failed to parse page...")
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\builder\_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381     parser.close()
#     382 except AssertionError as e:
#     383     # html.parser raises AssertionError in rare cases to
#     384     # indicate a fatal problem with the markup, especially
#     385     # when there's an error in the doctype declaration.
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\html\parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\html\parser.py:170, in HTMLParser.goahead(self, end)
#     168 if startswith('<', i):
#     169     if starttagopen.match(rawdata, i): # < + letter
# --> 170         k = self.parse_starttag(i)
#     171     elif startswith("</", i):
#     172         k = self.parse_endtag(i)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\html\parser.py:344, in HTMLParser.parse_starttag(self, i)
#     342     self.handle_startendtag(tag, attrs)
#     343 else:
# --> 344     self.handle_starttag(tag, attrs)
#     345     if tag in self.CDATA_CONTENT_ELEMENTS:
#     346         self.set_cdata_mode(tag)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\builder\_htmlparser.py:137, in BeautifulSoupHTMLParser.handle_starttag(self, name, attrs, handle_empty_element)
#     135 #print("START", name)
#     136 sourceline, sourcepos = self.getpos()
# --> 137 tag = self.soup.handle_starttag(
#     138     name, None, None, attr_dict, sourceline=sourceline,
#     139     sourcepos=sourcepos
#     140 )
#     141 if tag and tag.is_empty_element and handle_empty_element:
#     142     # Unlike other parsers, html.parser doesn't send separate end tag
#     143     # events for empty-element tags. (It's handled in
#    (...)
#     149     # don't want handle_endtag() to cross off any previous end
#     150     # events for tags of this name.
#     151     self.handle_endtag(name, check_already_closed=False)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\__init__.py:749, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     744 if (self.parse_only and len(self.tagStack) <= 1
#     745     and (self.parse_only.text
#     746          or not self.parse_only.search_tag(name, attrs))):
#     747     return None
# --> 749 tag = self.element_classes.get(Tag, Tag)(
#     750     self, self.builder, name, namespace, nsprefix, attrs,
#     751     self.currentTag, self._most_recent_element,
#     752     sourceline=sourceline, sourcepos=sourcepos,
#     753     namespaces=namespaces
#     754 )
#     755 if tag is None:
#     756     return tag
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\element.py:1262, in Tag.__init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags, interesting_string_types, namespaces)
#    1260 elif attrs:
#    1261     if builder is not None and builder.cdata_list_attributes:
# -> 1262         attrs = builder._replace_cdata_list_attribute_values(
#    1263             self.name, attrs)
#    1264     else:
#    1265         attrs = dict(attrs)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\builder\__init__.py:330, in TreeBuilder._replace_cdata_list_attribute_values(self, tag_name, attrs)
#     322             else:
#     323                 # html5lib sometimes calls setAttributes twice
#     324                 # for the same tag when rearranging the parse
#    (...)
#     327                 # leave the value alone rather than trying to
#     328                 # split it again.
#     329                 values = value
# --> 330             attrs[attr] = values
#     331 return attrs
#
# KeyboardInterrupt:
